# %% [markdown]
# <a href="https://colab.research.google.com/github/xBernardoVG/DNN-firstprinciples/blob/main/flows_example_poem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install crewai crewai-tools

# %%
pip freeze | grep crewai
# Out:
# crewai==0.98.0
# crewai-tools==0.32.1

# %%
# !crewai create crew PoemCrew
# Out:
# Creating folder poemcrew...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 2
# Enter your GEMINI API key (press Enter to skip): AIzaSyCbD0g1MF3no7BaxHuV2m9Om1aakq3AaEc
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-pro
#   - Created poemcrew/.gitignore
#   - Created poemcrew/pyproject.toml
#   - Created poemcrew/README.md
#   - Created poemcrew/knowledge/user_preference.txt
#   - Created poemcrew/src/poemcrew/__init__.py
#   - Created poemcrew/src/poemcrew/main.py
# ...

# %%
# !python /content/poemcrew/src/poemcrew/main.py
# Out:
#  Flow started with ID: 599397cc-1a71-44d5-a19b-0404177ccd8c
# Generating sentence count
# Generating poem
# LLM value is None
# # Agent: CrewAI Poem Writer
# ## Task: Write a poem about how CrewAI is awesome. Ensure the poem is engaging and adheres to the specified sentence count of 3.
#
#
#
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
# ERROR:root:LiteLLM call failed: litellm.InternalServerError: litellm.InternalServerError: VertexAIException - {
#   "error": {
#     "code": 503,
#     "message": "The model is overloaded. Please try again later.",
#     "status": "UNAVAILABLE"
#   }
# }
#
#
#
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
# ERROR:root:LiteLLM call failed: litellm.InternalServerError: VertexAIException InternalServerError - {
#   "error": {
#     "code": 500,
#     "message": "Unable to submit request because the service is temporarily unavailable.",
#     "status": "INTERNAL"
#   }
# }
#
#
#
# ...

# %%
# Out:
# sample_data  test1
