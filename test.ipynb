# %% [markdown]
# <a href="https://colab.research.google.com/github/xBernardoVG/DNN-firstprinciples/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install crewai crewai-tools

# %%
pip freeze | grep crewai
# Out:
# crewai==0.98.0
# crewai-tools==0.32.1

# %%
# !crewai create crew AiNews
# Out:
# Creating folder ainews...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyCbD0g1MF3no7BaxHuV2m9Om1aakq3AaEc
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created ainews/.gitignore
#   - Created ainews/pyproject.toml
#   - Created ainews/README.md
#   - Created ainews/knowledge/user_preference.txt
#   - Created ainews/src/ainews/__init__.py
#   - Created ainews/src/ainews/main.py
#   - Created ainews/src/ainews/crew.py
#   - Created ainews/src/ainews/tools/custom_tool.py
# ...

# %%
# %env SERPER_API_KEY c3a4a6192dd46ac3c28b57b9dc38d03375ee0ce5
# Out:
# env: SERPER_API_KEY=c3a4a6192dd46ac3c28b57b9dc38d03375ee0ce5

# %%
# !python /content/ainews/src/ainews/main.py
# Out:
# LLM value is None
# LLM value is None
# LLM value is None
# LLM value is None
# # Agent: AI LLMs AI news retriever
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2025.
#
#
#
# # Agent: AI LLMs AI news retriever
# ## Using tool: Search the internet with Serper
# ## Tool Input:
# "{\"search_query\": \"AI LLMs news 2025\"}"
# ## Tool Output:
# ...

# %%
# Out:
# sample_data  test1
